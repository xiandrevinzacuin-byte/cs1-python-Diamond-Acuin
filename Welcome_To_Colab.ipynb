# %% [markdown]
# <a href="https://colab.research.google.com/github/xiandrevinzacuin-byte/cs1-python-Diamond-Acuin/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
print"Hello Grade 7!"
